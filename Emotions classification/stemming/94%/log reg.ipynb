# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
# !unzip /usr/share/nltk_data/corpora/wordnet.zip -d /usr/share/nltk_data/corpora/
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train_root = "/kaggle/input/emotions-dataset-for-nlp/train.txt"
val_root =  "/kaggle/input/emotions-dataset-for-nlp/val.txt"
test_root =  "/kaggle/input/emotions-dataset-for-nlp/test.txt"

# %%
train_df = pd.read_csv(train_root, delimiter=";")
val_df = pd.read_csv(val_root, delimiter=";")
test_df = pd.read_csv(test_root, delimiter=";")
train_df.columns = ["text", "emotions"]
val_df.columns = ["text", "emotions"]
test_df.columns = ["text", "emotions"]

val_df = val_df.drop(val_df[(val_df['emotions'] == 'surprise') | (val_df['emotions'] == 'love')].index)
test_df = test_df.drop(test_df[(test_df['emotions'] == 'surprise') | (test_df['emotions'] == 'love')].index)
train_df = train_df.drop(train_df[(train_df['emotions'] == 'surprise') | (train_df['emotions'] == 'love')].index)
train_df['emotions'].value_counts()

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_df["emotions"])
y_val = label_encoder.fit_transform(val_df["emotions"])
y_test = label_encoder.fit_transform(test_df["emotions"])

X_train = train_df["text"]
X_val = val_df["text"]
X_test = test_df["text"]

# %%
def get_test_val_acc(model):
    model.fit(X_train, y_train)
    preds = model.predict(X_val)
    print(f"Val accuracy: {accuracy_score(preds, y_val)}")
    preds = model.predict(X_test)
    print(f"Test accuracy: {accuracy_score(preds, y_test)}")

# %%
models = [RandomForestClassifier(), LogisticRegression(), SVC(), KNeighborsClassifier()]

for model in models:
    clf = make_pipeline(CountVectorizer(), model)
    
    clf_name = type(clf).__name__  # Get the class name of the classifier
    print(f"Classifier: {model}")
    get_test_val_acc(clf)
    print("#" * 20)
# Out:
# Classifier: RandomForestClassifier()
# Val accuracy: 0.9057471264367816
# Test accuracy: 0.9216459977452086
# ####################
# Classifier: LogisticRegression()
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Val accuracy: 0.9321839080459771
# Test accuracy: 0.939120631341601
# ####################
# Classifier: SVC()
# Val accuracy: 0.8591954022988506
# Test accuracy: 0.8641488162344984
# ####################
# Classifier: KNeighborsClassifier()
# Val accuracy: 0.45
# Test accuracy: 0.4492671927846674
# ####################

# %%
models = [RandomForestClassifier(), LogisticRegression(), SVC(), KNeighborsClassifier()]

for model in models:
    clf = make_pipeline(TfidfVectorizer(stop_words="english", ngram_range=(1, 2)), model)
    
    clf_name = type(clf).__name__  # Get the class name of the classifier
    print(f"Classifier: {model}")
    get_test_val_acc(clf)
    print("#" * 20)
# Out:
# Classifier: RandomForestClassifier()
# Val accuracy: 0.9356321839080459
# Test accuracy: 0.9368658399098083
# ####################
# Classifier: LogisticRegression()
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Val accuracy: 0.9149425287356322
# Test accuracy: 0.9255918827508456
# ####################
# Classifier: SVC()
# Val accuracy: 0.9132183908045977
# Test accuracy: 0.9182638105975197
# ####################
# Classifier: KNeighborsClassifier()
# Val accuracy: 0.8040229885057472
# Test accuracy: 0.8151071025930101
# ####################

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('stopwords')
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))

def preprocess(text):    
    text_lower = text.lower()
    processed_text = re.sub('[^a-zA-Z]', ' ', text_lower)
    text_list = processed_text.split()
    stemmed_list = [stemmer.stem(word) for word in text_list if word not in stop_words]
    
    return " ".join(stemmed_list)
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
preprocessed_X_train = train_df["text"].apply(preprocess)
preprocessed_X_val = val_df["text"].apply(preprocess)
preprocessed_X_test = test_df["text"].apply(preprocess)

# %%
preprocessed_X_train[:5]
# Out:
# 0    go feel hopeless damn hope around someon care ...
# 1                 im grab minut post feel greedi wrong
# 3                                         feel grouchi
# 4                ive feel littl burden late wasnt sure
# 6            feel confus life teenag jade year old man
# Name: text, dtype: object

# %%
models = [RandomForestClassifier(), LogisticRegression(), SVC(), KNeighborsClassifier()]

for model in models:
    clf = make_pipeline(TfidfVectorizer(), model)
    
    clf_name = type(clf).__name__  # Get the class name of the classifier
    print(f"Classifier: {model}")
    clf.fit(preprocessed_X_train, y_train)
    preds = clf.predict(preprocessed_X_val)
    print(f"Val accuracy: {accuracy_score(preds, y_val)}")
    preds = clf.predict(preprocessed_X_test)
    print(f"Test accuracy: {accuracy_score(preds, y_test)}")
    print("#" * 20)
# Out:
# Classifier: RandomForestClassifier()
# Val accuracy: 0.8982758620689655
# Test accuracy: 0.9126268320180383
# ####################
# Classifier: LogisticRegression()
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Val accuracy: 0.889080459770115
# Test accuracy: 0.8979706877113867
# ####################
# Classifier: SVC()
# Val accuracy: 0.8833333333333333
# Test accuracy: 0.8957158962795941
# ####################
# Classifier: KNeighborsClassifier()
# Val accuracy: 0.8097701149425287
# Test accuracy: 0.8201803833145435
# ####################

# %%
models = [RandomForestClassifier(), LogisticRegression(), SVC(), KNeighborsClassifier()]

for model in models:
    clf = make_pipeline(CountVectorizer(), model)
    
    clf_name = type(clf).__name__  # Get the class name of the classifier
    print(f"Classifier: {model}")
    clf.fit(preprocessed_X_train, y_train)
    preds = clf.predict(preprocessed_X_val)
    print(f"Val accuracy: {accuracy_score(preds, y_val)}")
    preds = clf.predict(preprocessed_X_test)
    print(f"Test accuracy: {accuracy_score(preds, y_test)}")
    print("#" * 20)
# Out:
# Classifier: RandomForestClassifier()
# Val accuracy: 0.9005747126436782
# Test accuracy: 0.9092446448703495
# ####################
# Classifier: LogisticRegression()
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Val accuracy: 0.9017241379310345
# Test accuracy: 0.911499436302142
# ####################
# Classifier: SVC()
# Val accuracy: 0.8637931034482759
# Test accuracy: 0.8765501691093573
# ####################
# Classifier: KNeighborsClassifier()
# Val accuracy: 0.6994252873563218
# Test accuracy: 0.7001127395715896
# ####################

# %%
import xgboost as xgb
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score

vectorizer = CountVectorizer()

X_train_vec = vectorizer.fit_transform(preprocessed_X_train)
X_val_vec = vectorizer.transform(preprocessed_X_val)
X_test_vec = vectorizer.transform(preprocessed_X_test)

clf = xgb.XGBClassifier(objective='multi:softmax', 
                            num_class=4,
                            learning_rate=0.5,
                            n_estimators=200,  # Number of boosting rounds
                            early_stopping_rounds=10,  # Stop if no improvement for 10 rounds
                            eval_metric=['merror', 'mlogloss'],  # Evaluation metrics
                            seed=42)

clf.fit(X_train_vec, y_train, 
        eval_set=[(X_val_vec, y_val)],
        verbose=True)  # Set verbose to see training progress

# Evaluate on test set
preds_test = clf.predict(X_test_vec)
test_accuracy = accuracy_score(y_test, preds_test)
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# [0]	validation_0-merror:0.52989	validation_0-mlogloss:1.27385
# [1]	validation_0-merror:0.46897	validation_0-mlogloss:1.19239
# [2]	validation_0-merror:0.39540	validation_0-mlogloss:1.12548
# [3]	validation_0-merror:0.34655	validation_0-mlogloss:1.06977
# [4]	validation_0-merror:0.31092	validation_0-mlogloss:1.02378
# [5]	validation_0-merror:0.29425	validation_0-mlogloss:0.98629
# [6]	validation_0-merror:0.26954	validation_0-mlogloss:0.94866
# [7]	validation_0-merror:0.25632	validation_0-mlogloss:0.92037
# [8]	validation_0-merror:0.24253	validation_0-mlogloss:0.89120
# [9]	validation_0-merror:0.21494	validation_0-mlogloss:0.86159
# [10]	validation_0-merror:0.18678	validation_0-mlogloss:0.83458
# [11]	validation_0-merror:0.17011	validation_0-mlogloss:0.81357
# [12]	validation_0-merror:0.15000	validation_0-mlogloss:0.79018
# [13]	validation_0-merror:0.14023	validation_0-mlogloss:0.77415
# [14]	validation_0-merror:0.14023	validation_0-mlogloss:0.75730
# [15]	validation_0-merror:0.13391	validation_0-mlogloss:0.74435
# [16]	validation_0-merror:0.13391	validation_0-mlogloss:0.72824
# [17]	validation_0-merror:0.13621	validation_0-mlogloss:0.71046
# [18]	validation_0-merror:0.13276	validation_0-mlogloss:0.69492
# [19]	validation_0-merror:0.13276	validation_0-mlogloss:0.68202
# [20]	validation_0-merror:0.13276	validation_0-mlogloss:0.67024
# [21]	validation_0-merror:0.13103	validation_0-mlogloss:0.65846
# [22]	validation_0-merror:0.13103	validation_0-mlogloss:0.64784
# [23]	validation_0-merror:0.12816	validation_0-mlogloss:0.63582
# [24]	validation_0-merror:0.12414	validation_0-mlogloss:0.62492
# [25]	validation_0-merror:0.12356	validation_0-mlogloss:0.61373
# [26]	validation_0-merror:0.12184	validation_0-mlogloss:0.60477
# [27]	validation_0-merror:0.11609	validation_0-mlogloss:0.59407
# [28]	validation_0-merror:0.11552	validation_0-mlogloss:0.58565
# [29]	validation_0-merror:0.11609	validation_0-mlogloss:0.57738
# [30]	validation_0-merror:0.11954	validation_0-mlogloss:0.56849
# [31]	validation_0-merror:0.11897	validation_0-mlogloss:0.55888
# [32]	validation_0-merror:0.11839	validation_0-mlogloss:0.54953
# [33]	validation_0-merror:0.12011	validation_0-mlogloss:0.54371
# [34]	validation_0-merror:0.12011	validation_0-mlogloss:0.53686
# [35]	validation_0-merror:0.11782	validation_0-mlogloss:0.53049
# [36]	validation_0-merror:0.11724	validation_0-mlogloss:0.52429
# [37]	validation_0-merror:0.11494	validation_0-mlogloss:0.51565
# [38]	validation_0-merror:0.11552	validation_0-mlogloss:0.50963
# [39]	validation_0-merror:0.11322	validation_0-mlogloss:0.50291
# [40]	validation_0-merror:0.10977	validation_0-mlogloss:0.49771
# [41]	validation_0-merror:0.11092	validation_0-mlogloss:0.49215
# [42]	validation_0-merror:0.10977	validation_0-mlogloss:0.48626
# [43]	validation_0-merror:0.10862	validation_0-mlogloss:0.48139
# [44]	validation_0-merror:0.10805	validation_0-mlogloss:0.47719
# [45]	validation_0-merror:0.11034	validation_0-mlogloss:0.47216
# [46]	validation_0-merror:0.11034	validation_0-mlogloss:0.46721
# [47]	validation_0-merror:0.10920	validation_0-mlogloss:0.46100
# [48]	validation_0-merror:0.10977	validation_0-mlogloss:0.45582
# [49]	validation_0-merror:0.10690	validation_0-mlogloss:0.45037
# [50]	validation_0-merror:0.10690	validation_0-mlogloss:0.44499
# [51]	validation_0-merror:0.10747	validation_0-mlogloss:0.44144
# [52]	validation_0-merror:0.10575	validation_0-mlogloss:0.43656
# [53]	validation_0-merror:0.10460	validation_0-mlogloss:0.43244
# [54]	validation_0-merror:0.10747	validation_0-mlogloss:0.42974
# [55]	validation_0-merror:0.10632	validation_0-mlogloss:0.42633
# [56]	validation_0-merror:0.10747	validation_0-mlogloss:0.42113
# [57]	validation_0-merror:0.10690	validation_0-mlogloss:0.41859
# [58]	validation_0-merror:0.10575	validation_0-mlogloss:0.41453
# [59]	validation_0-merror:0.10460	validation_0-mlogloss:0.41081
# [60]	validation_0-merror:0.10575	validation_0-mlogloss:0.40818
# [61]	validation_0-merror:0.10690	validation_0-mlogloss:0.40497
# [62]	validation_0-merror:0.10747	validation_0-mlogloss:0.40204
# [63]	validation_0-merror:0.10517	validation_0-mlogloss:0.39737
# [64]	validation_0-merror:0.10402	validation_0-mlogloss:0.39385
# [65]	validation_0-merror:0.10230	validation_0-mlogloss:0.39014
# [66]	validation_0-merror:0.10345	validation_0-mlogloss:0.38718
# [67]	validation_0-merror:0.10230	validation_0-mlogloss:0.38396
# [68]	validation_0-merror:0.10230	validation_0-mlogloss:0.38134
# [69]	validation_0-merror:0.10172	validation_0-mlogloss:0.37858
# [70]	validation_0-merror:0.10172	validation_0-mlogloss:0.37514
# [71]	validation_0-merror:0.10115	validation_0-mlogloss:0.37210
# [72]	validation_0-merror:0.10172	validation_0-mlogloss:0.36923
# [73]	validation_0-merror:0.10172	validation_0-mlogloss:0.36754
# [74]	validation_0-merror:0.10172	validation_0-mlogloss:0.36498
# [75]	validation_0-merror:0.10057	validation_0-mlogloss:0.36249
# [76]	validation_0-merror:0.09828	validation_0-mlogloss:0.35962
# [77]	validation_0-merror:0.09713	validation_0-mlogloss:0.35736
# [78]	validation_0-merror:0.09885	validation_0-mlogloss:0.35434
# [79]	validation_0-merror:0.09885	validation_0-mlogloss:0.35290
# [80]	validation_0-merror:0.09943	validation_0-mlogloss:0.35016
# [81]	validation_0-merror:0.10000	validation_0-mlogloss:0.34807
# [82]	validation_0-merror:0.10057	validation_0-mlogloss:0.34554
# [83]	validation_0-merror:0.09885	validation_0-mlogloss:0.34370
# [84]	validation_0-merror:0.09828	validation_0-mlogloss:0.34144
# [85]	validation_0-merror:0.09713	validation_0-mlogloss:0.33932
# [86]	validation_0-merror:0.10000	validation_0-mlogloss:0.33707
# [87]	validation_0-merror:0.10000	validation_0-mlogloss:0.33569
# [88]	validation_0-merror:0.09885	validation_0-mlogloss:0.33485
# [89]	validation_0-merror:0.10057	validation_0-mlogloss:0.33367
# [90]	validation_0-merror:0.09770	validation_0-mlogloss:0.33158
# [91]	validation_0-merror:0.09943	validation_0-mlogloss:0.32947
# [92]	validation_0-merror:0.09655	validation_0-mlogloss:0.32761
# [93]	validation_0-merror:0.10000	validation_0-mlogloss:0.32614
# [94]	validation_0-merror:0.09713	validation_0-mlogloss:0.32393
# [95]	validation_0-merror:0.09943	validation_0-mlogloss:0.32211
# [96]	validation_0-merror:0.09943	validation_0-mlogloss:0.32046
# [97]	validation_0-merror:0.09885	validation_0-mlogloss:0.31902
# [98]	validation_0-merror:0.09885	validation_0-mlogloss:0.31668
# [99]	validation_0-merror:0.10057	validation_0-mlogloss:0.31529
# [100]	validation_0-merror:0.09943	validation_0-mlogloss:0.31460
# [101]	validation_0-merror:0.09885	validation_0-mlogloss:0.31340
# [102]	validation_0-merror:0.10057	validation_0-mlogloss:0.31271
# [103]	validation_0-merror:0.10115	validation_0-mlogloss:0.31115
# [104]	validation_0-merror:0.09885	validation_0-mlogloss:0.30966
# [105]	validation_0-merror:0.09713	validation_0-mlogloss:0.30791
# [106]	validation_0-merror:0.09943	validation_0-mlogloss:0.30630
# [107]	validation_0-merror:0.09770	validation_0-mlogloss:0.30518
# [108]	validation_0-merror:0.09770	validation_0-mlogloss:0.30365
# [109]	validation_0-merror:0.09713	validation_0-mlogloss:0.30177
# [110]	validation_0-merror:0.09713	validation_0-mlogloss:0.30063
# [111]	validation_0-merror:0.09770	validation_0-mlogloss:0.29951
# [112]	validation_0-merror:0.09655	validation_0-mlogloss:0.29764
# [113]	validation_0-merror:0.09598	validation_0-mlogloss:0.29693
# [114]	validation_0-merror:0.09425	validation_0-mlogloss:0.29532
# [115]	validation_0-merror:0.09368	validation_0-mlogloss:0.29475
# [116]	validation_0-merror:0.09253	validation_0-mlogloss:0.29333
# [117]	validation_0-merror:0.09368	validation_0-mlogloss:0.29266
# [118]	validation_0-merror:0.09310	validation_0-mlogloss:0.29129
# [119]	validation_0-merror:0.09425	validation_0-mlogloss:0.29078
# [120]	validation_0-merror:0.09770	validation_0-mlogloss:0.28971
# [121]	validation_0-merror:0.09713	validation_0-mlogloss:0.28858
# [122]	validation_0-merror:0.09713	validation_0-mlogloss:0.28728
# [123]	validation_0-merror:0.09655	validation_0-mlogloss:0.28658
# [124]	validation_0-merror:0.09598	validation_0-mlogloss:0.28516
# [125]	validation_0-merror:0.09770	validation_0-mlogloss:0.28437
# [126]	validation_0-merror:0.09770	validation_0-mlogloss:0.28346
# [127]	validation_0-merror:0.09770	validation_0-mlogloss:0.28254
# [128]	validation_0-merror:0.09713	validation_0-mlogloss:0.28195
# [129]	validation_0-merror:0.09885	validation_0-mlogloss:0.28195
# [130]	validation_0-merror:0.09770	validation_0-mlogloss:0.28119
# [131]	validation_0-merror:0.09540	validation_0-mlogloss:0.27981
# [132]	validation_0-merror:0.09598	validation_0-mlogloss:0.27931
# [133]	validation_0-merror:0.09368	validation_0-mlogloss:0.27815
# [134]	validation_0-merror:0.09310	validation_0-mlogloss:0.27733
# [135]	validation_0-merror:0.09310	validation_0-mlogloss:0.27706
# [136]	validation_0-merror:0.09195	validation_0-mlogloss:0.27578
# [137]	validation_0-merror:0.09195	validation_0-mlogloss:0.27472
# [138]	validation_0-merror:0.09253	validation_0-mlogloss:0.27392
# [139]	validation_0-merror:0.09483	validation_0-mlogloss:0.27339
# [140]	validation_0-merror:0.09368	validation_0-mlogloss:0.27292
# [141]	validation_0-merror:0.09540	validation_0-mlogloss:0.27214
# [142]	validation_0-merror:0.09540	validation_0-mlogloss:0.27159
# [143]	validation_0-merror:0.09540	validation_0-mlogloss:0.27145
# [144]	validation_0-merror:0.09655	validation_0-mlogloss:0.27044
# [145]	validation_0-merror:0.09598	validation_0-mlogloss:0.26902
# [146]	validation_0-merror:0.09540	validation_0-mlogloss:0.26771
# [147]	validation_0-merror:0.09540	validation_0-mlogloss:0.26752
# [148]	validation_0-merror:0.09540	validation_0-mlogloss:0.26742
# [149]	validation_0-merror:0.09540	validation_0-mlogloss:0.26667
# [150]	validation_0-merror:0.09655	validation_0-mlogloss:0.26566
# [151]	validation_0-merror:0.09655	validation_0-mlogloss:0.26574
# [152]	validation_0-merror:0.09713	validation_0-mlogloss:0.26485
# [153]	validation_0-merror:0.09540	validation_0-mlogloss:0.26424
# [154]	validation_0-merror:0.09425	validation_0-mlogloss:0.26329
# [155]	validation_0-merror:0.09425	validation_0-mlogloss:0.26254
# [156]	validation_0-merror:0.09598	validation_0-mlogloss:0.26249
# [157]	validation_0-merror:0.09598	validation_0-mlogloss:0.26198
# [158]	validation_0-merror:0.09598	validation_0-mlogloss:0.26204
# [159]	validation_0-merror:0.09598	validation_0-mlogloss:0.26128
# [160]	validation_0-merror:0.09598	validation_0-mlogloss:0.26108
# [161]	validation_0-merror:0.09483	validation_0-mlogloss:0.26033
# [162]	validation_0-merror:0.09368	validation_0-mlogloss:0.25975
# [163]	validation_0-merror:0.09425	validation_0-mlogloss:0.25876
# [164]	validation_0-merror:0.09368	validation_0-mlogloss:0.25806
# [165]	validation_0-merror:0.09310	validation_0-mlogloss:0.25740
# [166]	validation_0-merror:0.09253	validation_0-mlogloss:0.25663
# [167]	validation_0-merror:0.09195	validation_0-mlogloss:0.25537
# [168]	validation_0-merror:0.09138	validation_0-mlogloss:0.25537
# [169]	validation_0-merror:0.09138	validation_0-mlogloss:0.25470
# [170]	validation_0-merror:0.09138	validation_0-mlogloss:0.25410
# [171]	validation_0-merror:0.09023	validation_0-mlogloss:0.25361
# [172]	validation_0-merror:0.09023	validation_0-mlogloss:0.25333
# [173]	validation_0-merror:0.08966	validation_0-mlogloss:0.25232
# [174]	validation_0-merror:0.09080	validation_0-mlogloss:0.25225
# [175]	validation_0-merror:0.09138	validation_0-mlogloss:0.25179
# [176]	validation_0-merror:0.08966	validation_0-mlogloss:0.25113
# [177]	validation_0-merror:0.09023	validation_0-mlogloss:0.25077
# [178]	validation_0-merror:0.09080	validation_0-mlogloss:0.25088
# [179]	validation_0-merror:0.09138	validation_0-mlogloss:0.25051
# [180]	validation_0-merror:0.09138	validation_0-mlogloss:0.25047
# [181]	validation_0-merror:0.09195	validation_0-mlogloss:0.24976
# [182]	validation_0-merror:0.09195	validation_0-mlogloss:0.24890
# [183]	validation_0-merror:0.09195	validation_0-mlogloss:0.24859
# [184]	validation_0-merror:0.09138	validation_0-mlogloss:0.24804
# [185]	validation_0-merror:0.09253	validation_0-mlogloss:0.24760
# [186]	validation_0-merror:0.09195	validation_0-mlogloss:0.24722
# [187]	validation_0-merror:0.09138	validation_0-mlogloss:0.24702
# [188]	validation_0-merror:0.09138	validation_0-mlogloss:0.24706
# [189]	validation_0-merror:0.09080	validation_0-mlogloss:0.24666
# [190]	validation_0-merror:0.09080	validation_0-mlogloss:0.24628
# [191]	validation_0-merror:0.09023	validation_0-mlogloss:0.24603
# [192]	validation_0-merror:0.08966	validation_0-mlogloss:0.24552
# [193]	validation_0-merror:0.08966	validation_0-mlogloss:0.24519
# [194]	validation_0-merror:0.09023	validation_0-mlogloss:0.24453
# [195]	validation_0-merror:0.09080	validation_0-mlogloss:0.24415
# [196]	validation_0-merror:0.09138	validation_0-mlogloss:0.24388
# [197]	validation_0-merror:0.09138	validation_0-mlogloss:0.24385
# [198]	validation_0-merror:0.09138	validation_0-mlogloss:0.24374
# [199]	validation_0-merror:0.09080	validation_0-mlogloss:0.24299
# Test accuracy: 0.9267

# %%
import xgboost as xgb
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score

vectorizer = TfidfVectorizer()

X_train_vec = vectorizer.fit_transform(preprocessed_X_train)
X_val_vec = vectorizer.transform(preprocessed_X_val)
X_test_vec = vectorizer.transform(preprocessed_X_test)

clf = xgb.XGBClassifier(objective='multi:softmax', 
                            num_class=4,
                            learning_rate=0.5,
                            n_estimators=200,  # Number of boosting rounds
                            early_stopping_rounds=10,  # Stop if no improvement for 10 rounds
                            eval_metric=['merror', 'mlogloss'],  # Evaluation metrics
                            seed=42)

clf.fit(X_train_vec, y_train, 
        eval_set=[(X_val_vec, y_val)],
        verbose=True)  # Set verbose to see training progress

# Evaluate on test set
preds_test = clf.predict(X_test_vec)
test_accuracy = accuracy_score(y_test, preds_test)
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# [0]	validation_0-merror:0.53391	validation_0-mlogloss:1.27528
# [1]	validation_0-merror:0.47126	validation_0-mlogloss:1.19577
# [2]	validation_0-merror:0.40632	validation_0-mlogloss:1.13079
# [3]	validation_0-merror:0.34770	validation_0-mlogloss:1.06911
# [4]	validation_0-merror:0.31667	validation_0-mlogloss:1.02220
# [5]	validation_0-merror:0.28793	validation_0-mlogloss:0.98380
# [6]	validation_0-merror:0.26782	validation_0-mlogloss:0.94587
# [7]	validation_0-merror:0.25747	validation_0-mlogloss:0.92025
# [8]	validation_0-merror:0.23506	validation_0-mlogloss:0.89188
# [9]	validation_0-merror:0.20920	validation_0-mlogloss:0.86183
# [10]	validation_0-merror:0.18793	validation_0-mlogloss:0.83529
# [11]	validation_0-merror:0.17011	validation_0-mlogloss:0.81260
# [12]	validation_0-merror:0.15172	validation_0-mlogloss:0.79241
# [13]	validation_0-merror:0.14425	validation_0-mlogloss:0.77310
# [14]	validation_0-merror:0.14195	validation_0-mlogloss:0.75647
# [15]	validation_0-merror:0.14023	validation_0-mlogloss:0.74109
# [16]	validation_0-merror:0.14080	validation_0-mlogloss:0.72517
# [17]	validation_0-merror:0.13563	validation_0-mlogloss:0.71156
# [18]	validation_0-merror:0.13276	validation_0-mlogloss:0.69342
# [19]	validation_0-merror:0.13506	validation_0-mlogloss:0.68331
# [20]	validation_0-merror:0.13563	validation_0-mlogloss:0.66934
# [21]	validation_0-merror:0.13678	validation_0-mlogloss:0.65965
# [22]	validation_0-merror:0.13103	validation_0-mlogloss:0.64742
# [23]	validation_0-merror:0.12816	validation_0-mlogloss:0.63577
# [24]	validation_0-merror:0.12931	validation_0-mlogloss:0.62555
# [25]	validation_0-merror:0.12759	validation_0-mlogloss:0.61357
# [26]	validation_0-merror:0.12414	validation_0-mlogloss:0.60387
# [27]	validation_0-merror:0.12184	validation_0-mlogloss:0.59682
# [28]	validation_0-merror:0.12241	validation_0-mlogloss:0.58819
# [29]	validation_0-merror:0.12471	validation_0-mlogloss:0.57870
# [30]	validation_0-merror:0.11839	validation_0-mlogloss:0.56741
# [31]	validation_0-merror:0.11667	validation_0-mlogloss:0.56032
# [32]	validation_0-merror:0.11609	validation_0-mlogloss:0.55171
# [33]	validation_0-merror:0.11552	validation_0-mlogloss:0.54387
# [34]	validation_0-merror:0.11494	validation_0-mlogloss:0.53756
# [35]	validation_0-merror:0.11322	validation_0-mlogloss:0.53148
# [36]	validation_0-merror:0.11149	validation_0-mlogloss:0.52469
# [37]	validation_0-merror:0.10977	validation_0-mlogloss:0.51781
# [38]	validation_0-merror:0.10920	validation_0-mlogloss:0.51247
# [39]	validation_0-merror:0.11092	validation_0-mlogloss:0.50550
# [40]	validation_0-merror:0.10920	validation_0-mlogloss:0.49852
# [41]	validation_0-merror:0.11092	validation_0-mlogloss:0.49315
# [42]	validation_0-merror:0.10460	validation_0-mlogloss:0.48677
# [43]	validation_0-merror:0.10287	validation_0-mlogloss:0.48245
# [44]	validation_0-merror:0.10230	validation_0-mlogloss:0.47748
# [45]	validation_0-merror:0.10287	validation_0-mlogloss:0.47241
# [46]	validation_0-merror:0.10402	validation_0-mlogloss:0.46668
# [47]	validation_0-merror:0.10345	validation_0-mlogloss:0.46118
# [48]	validation_0-merror:0.10287	validation_0-mlogloss:0.45684
# [49]	validation_0-merror:0.10805	validation_0-mlogloss:0.45216
# [50]	validation_0-merror:0.10575	validation_0-mlogloss:0.44896
# [51]	validation_0-merror:0.10632	validation_0-mlogloss:0.44392
# [52]	validation_0-merror:0.10345	validation_0-mlogloss:0.44036
# [53]	validation_0-merror:0.10632	validation_0-mlogloss:0.43647
# [54]	validation_0-merror:0.10862	validation_0-mlogloss:0.43321
# [55]	validation_0-merror:0.10805	validation_0-mlogloss:0.42876
# [56]	validation_0-merror:0.10690	validation_0-mlogloss:0.42501
# [57]	validation_0-merror:0.10747	validation_0-mlogloss:0.42096
# [58]	validation_0-merror:0.10632	validation_0-mlogloss:0.41702
# [59]	validation_0-merror:0.10402	validation_0-mlogloss:0.41219
# [60]	validation_0-merror:0.10632	validation_0-mlogloss:0.41020
# [61]	validation_0-merror:0.10575	validation_0-mlogloss:0.40664
# [62]	validation_0-merror:0.10517	validation_0-mlogloss:0.40470
# [63]	validation_0-merror:0.10690	validation_0-mlogloss:0.40126
# [64]	validation_0-merror:0.10575	validation_0-mlogloss:0.39831
# [65]	validation_0-merror:0.10517	validation_0-mlogloss:0.39548
# [66]	validation_0-merror:0.10575	validation_0-mlogloss:0.39237
# [67]	validation_0-merror:0.10805	validation_0-mlogloss:0.38924
# [68]	validation_0-merror:0.10575	validation_0-mlogloss:0.38791
# [69]	validation_0-merror:0.10517	validation_0-mlogloss:0.38337
# [70]	validation_0-merror:0.10345	validation_0-mlogloss:0.37999
# [71]	validation_0-merror:0.10172	validation_0-mlogloss:0.37680
# [72]	validation_0-merror:0.10057	validation_0-mlogloss:0.37396
# [73]	validation_0-merror:0.09885	validation_0-mlogloss:0.37131
# [74]	validation_0-merror:0.09885	validation_0-mlogloss:0.36994
# [75]	validation_0-merror:0.09885	validation_0-mlogloss:0.36693
# [76]	validation_0-merror:0.09713	validation_0-mlogloss:0.36415
# [77]	validation_0-merror:0.09655	validation_0-mlogloss:0.36184
# [78]	validation_0-merror:0.09655	validation_0-mlogloss:0.35860
# [79]	validation_0-merror:0.09540	validation_0-mlogloss:0.35625
# [80]	validation_0-merror:0.09655	validation_0-mlogloss:0.35369
# [81]	validation_0-merror:0.09598	validation_0-mlogloss:0.35155
# [82]	validation_0-merror:0.09598	validation_0-mlogloss:0.35009
# [83]	validation_0-merror:0.09540	validation_0-mlogloss:0.34800
# [84]	validation_0-merror:0.09598	validation_0-mlogloss:0.34673
# [85]	validation_0-merror:0.09540	validation_0-mlogloss:0.34484
# [86]	validation_0-merror:0.09425	validation_0-mlogloss:0.34280
# [87]	validation_0-merror:0.09540	validation_0-mlogloss:0.34042
# [88]	validation_0-merror:0.09368	validation_0-mlogloss:0.33899
# [89]	validation_0-merror:0.09253	validation_0-mlogloss:0.33711
# [90]	validation_0-merror:0.09023	validation_0-mlogloss:0.33503
# [91]	validation_0-merror:0.09138	validation_0-mlogloss:0.33375
# [92]	validation_0-merror:0.09253	validation_0-mlogloss:0.33201
# [93]	validation_0-merror:0.09253	validation_0-mlogloss:0.32920
# [94]	validation_0-merror:0.09310	validation_0-mlogloss:0.32782
# [95]	validation_0-merror:0.09368	validation_0-mlogloss:0.32626
# [96]	validation_0-merror:0.09368	validation_0-mlogloss:0.32430
# [97]	validation_0-merror:0.09368	validation_0-mlogloss:0.32317
# [98]	validation_0-merror:0.09310	validation_0-mlogloss:0.32230
# [99]	validation_0-merror:0.09195	validation_0-mlogloss:0.32086
# [100]	validation_0-merror:0.09195	validation_0-mlogloss:0.32001
# [101]	validation_0-merror:0.09310	validation_0-mlogloss:0.31821
# [102]	validation_0-merror:0.09310	validation_0-mlogloss:0.31707
# [103]	validation_0-merror:0.09425	validation_0-mlogloss:0.31570
# [104]	validation_0-merror:0.09253	validation_0-mlogloss:0.31481
# [105]	validation_0-merror:0.09253	validation_0-mlogloss:0.31326
# [106]	validation_0-merror:0.09253	validation_0-mlogloss:0.31278
# [107]	validation_0-merror:0.09368	validation_0-mlogloss:0.31173
# [108]	validation_0-merror:0.09368	validation_0-mlogloss:0.31109
# [109]	validation_0-merror:0.09195	validation_0-mlogloss:0.30941
# [110]	validation_0-merror:0.09253	validation_0-mlogloss:0.30822
# [111]	validation_0-merror:0.09138	validation_0-mlogloss:0.30745
# [112]	validation_0-merror:0.09253	validation_0-mlogloss:0.30588
# [113]	validation_0-merror:0.09310	validation_0-mlogloss:0.30501
# [114]	validation_0-merror:0.09310	validation_0-mlogloss:0.30399
# [115]	validation_0-merror:0.09368	validation_0-mlogloss:0.30297
# [116]	validation_0-merror:0.09253	validation_0-mlogloss:0.30162
# [117]	validation_0-merror:0.09080	validation_0-mlogloss:0.30062
# [118]	validation_0-merror:0.09080	validation_0-mlogloss:0.29955
# [119]	validation_0-merror:0.09195	validation_0-mlogloss:0.29886
# [120]	validation_0-merror:0.09253	validation_0-mlogloss:0.29828
# [121]	validation_0-merror:0.09253	validation_0-mlogloss:0.29699
# [122]	validation_0-merror:0.09138	validation_0-mlogloss:0.29640
# [123]	validation_0-merror:0.09138	validation_0-mlogloss:0.29521
# [124]	validation_0-merror:0.09195	validation_0-mlogloss:0.29445
# [125]	validation_0-merror:0.09195	validation_0-mlogloss:0.29367
# [126]	validation_0-merror:0.09195	validation_0-mlogloss:0.29198
# [127]	validation_0-merror:0.09195	validation_0-mlogloss:0.29106
# [128]	validation_0-merror:0.09138	validation_0-mlogloss:0.28986
# [129]	validation_0-merror:0.09195	validation_0-mlogloss:0.28955
# [130]	validation_0-merror:0.09080	validation_0-mlogloss:0.28794
# [131]	validation_0-merror:0.09138	validation_0-mlogloss:0.28758
# [132]	validation_0-merror:0.09138	validation_0-mlogloss:0.28730
# [133]	validation_0-merror:0.09195	validation_0-mlogloss:0.28636
# [134]	validation_0-merror:0.09195	validation_0-mlogloss:0.28517
# [135]	validation_0-merror:0.09310	validation_0-mlogloss:0.28501
# [136]	validation_0-merror:0.09310	validation_0-mlogloss:0.28399
# [137]	validation_0-merror:0.09138	validation_0-mlogloss:0.28275
# [138]	validation_0-merror:0.09138	validation_0-mlogloss:0.28187
# [139]	validation_0-merror:0.09080	validation_0-mlogloss:0.28125
# [140]	validation_0-merror:0.08966	validation_0-mlogloss:0.28027
# [141]	validation_0-merror:0.08851	validation_0-mlogloss:0.27977
# [142]	validation_0-merror:0.08851	validation_0-mlogloss:0.27937
# [143]	validation_0-merror:0.08908	validation_0-mlogloss:0.27849
# [144]	validation_0-merror:0.08908	validation_0-mlogloss:0.27774
# [145]	validation_0-merror:0.08908	validation_0-mlogloss:0.27689
# [146]	validation_0-merror:0.08966	validation_0-mlogloss:0.27601
# [147]	validation_0-merror:0.09023	validation_0-mlogloss:0.27575
# [148]	validation_0-merror:0.09138	validation_0-mlogloss:0.27432
# [149]	validation_0-merror:0.09195	validation_0-mlogloss:0.27353
# [150]	validation_0-merror:0.09195	validation_0-mlogloss:0.27239
# [151]	validation_0-merror:0.09195	validation_0-mlogloss:0.27185
# [152]	validation_0-merror:0.09138	validation_0-mlogloss:0.27122
# [153]	validation_0-merror:0.09080	validation_0-mlogloss:0.27098
# [154]	validation_0-merror:0.09080	validation_0-mlogloss:0.27056
# [155]	validation_0-merror:0.09138	validation_0-mlogloss:0.27021
# [156]	validation_0-merror:0.09080	validation_0-mlogloss:0.26927
# [157]	validation_0-merror:0.09138	validation_0-mlogloss:0.26963
# [158]	validation_0-merror:0.09080	validation_0-mlogloss:0.26889
# [159]	validation_0-merror:0.09195	validation_0-mlogloss:0.26873
# [160]	validation_0-merror:0.09195	validation_0-mlogloss:0.26818
# [161]	validation_0-merror:0.09195	validation_0-mlogloss:0.26821
# [162]	validation_0-merror:0.09368	validation_0-mlogloss:0.26737
# [163]	validation_0-merror:0.09310	validation_0-mlogloss:0.26704
# [164]	validation_0-merror:0.09195	validation_0-mlogloss:0.26659
# [165]	validation_0-merror:0.09195	validation_0-mlogloss:0.26633
# [166]	validation_0-merror:0.09195	validation_0-mlogloss:0.26543
# [167]	validation_0-merror:0.09195	validation_0-mlogloss:0.26506
# [168]	validation_0-merror:0.09195	validation_0-mlogloss:0.26472
# [169]	validation_0-merror:0.09138	validation_0-mlogloss:0.26390
# [170]	validation_0-merror:0.09138	validation_0-mlogloss:0.26382
# [171]	validation_0-merror:0.09080	validation_0-mlogloss:0.26377
# [172]	validation_0-merror:0.09023	validation_0-mlogloss:0.26311
# [173]	validation_0-merror:0.09023	validation_0-mlogloss:0.26278
# [174]	validation_0-merror:0.09080	validation_0-mlogloss:0.26219
# [175]	validation_0-merror:0.09138	validation_0-mlogloss:0.26183
# [176]	validation_0-merror:0.09138	validation_0-mlogloss:0.26129
# [177]	validation_0-merror:0.09138	validation_0-mlogloss:0.26081
# [178]	validation_0-merror:0.09023	validation_0-mlogloss:0.26035
# [179]	validation_0-merror:0.09023	validation_0-mlogloss:0.25939
# [180]	validation_0-merror:0.08966	validation_0-mlogloss:0.25924
# [181]	validation_0-merror:0.09138	validation_0-mlogloss:0.25857
# [182]	validation_0-merror:0.09023	validation_0-mlogloss:0.25836
# [183]	validation_0-merror:0.08966	validation_0-mlogloss:0.25794
# [184]	validation_0-merror:0.09023	validation_0-mlogloss:0.25786
# [185]	validation_0-merror:0.09023	validation_0-mlogloss:0.25762
# [186]	validation_0-merror:0.09023	validation_0-mlogloss:0.25788
# [187]	validation_0-merror:0.08908	validation_0-mlogloss:0.25779
# [188]	validation_0-merror:0.09138	validation_0-mlogloss:0.25770
# [189]	validation_0-merror:0.09138	validation_0-mlogloss:0.25731
# [190]	validation_0-merror:0.09080	validation_0-mlogloss:0.25732
# [191]	validation_0-merror:0.09138	validation_0-mlogloss:0.25688
# [192]	validation_0-merror:0.09138	validation_0-mlogloss:0.25600
# [193]	validation_0-merror:0.09023	validation_0-mlogloss:0.25483
# [194]	validation_0-merror:0.08966	validation_0-mlogloss:0.25410
# [195]	validation_0-merror:0.08908	validation_0-mlogloss:0.25396
# [196]	validation_0-merror:0.08966	validation_0-mlogloss:0.25365
# [197]	validation_0-merror:0.08908	validation_0-mlogloss:0.25360
# [198]	validation_0-merror:0.08851	validation_0-mlogloss:0.25282
# [199]	validation_0-merror:0.08793	validation_0-mlogloss:0.25308
# Test accuracy: 0.9183

# %% [markdown]
# # **Conclusion**
# # The best performing model was logistic regression achieveing 93.9% on the test set.
# # It was also the fastest one.
